# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniChinwendu/DATA-CAMP-ASSIGNMENT/blob/main/Pandas_data_manipulation_techniques_(Data_insight).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas is unarguably one if the best things that has happened to data science in python. This module helps us navigate through different data science workflow with ease and precision.In this tutorial we are going to dive through five pandas data manipulation techniques for pandas. There are numerous data manipulation techniques in python. I would recommend you research a learn more about this techniques your self.

# %%
#First we import the pandas module
import pandas as pd
#because we are using the Google colab code notebook it is important we import our dataset
from google.colab import files
Upload=files.upload()
# Out:
#      <input type="file" id="files-2882e635-4d1d-4a95-9042-1451a2ae1ea3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2882e635-4d1d-4a95-9042-1451a2ae1ea3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# For this operation we will be using the student adaptability level dataset we have use previously.

# %%
df=pd.read_csv('INC 5000 Companies 2019.csv')

# %% [markdown]
# EMERGING DATA FRAMES WITH PANDAS

# %%
df.head()
# Out:
#    rank                                   profile               name  \
# 0     1      https://www.inc.com/profile/freestar           Freestar
# 1     2   https://www.inc.com/profile/freightwise        FreightWise
# 2     3  https://www.inc.com/profile/ceces-veggie  Cece's Veggie Co.
# 3     4      https://www.inc.com/profile/ladyboss           LadyBoss
# 4     5        https://www.inc.com/profile/perpay             Perpay
#
#                          url state       revenue    growth_%  \
# 0        http://freestar.com    AZ  36.9 Million  36680.3882
# 1  http://freightwisellc.com    TN  33.6 Million  30547.9317
# 2   http://cecesveggieco.com    TX  24.9 Million  23880.4852
# 3        http://ladyboss.com    NM  32.4 Million  21849.8925
# 4          http://perpay.com    PA  22.5 Million  18166.4070
#
#                        industry  workers  previous_workers  founded  \
# 0       Advertising & Marketing     40.0                 5     2015
# ...

# %%
df.describe()
# Out:
#               rank      growth_%        workers  previous_workers  \
# count  5012.000000   5012.000000    5011.000000       5012.000000
# mean   2499.628292    454.680059     242.783077        111.687151
# std    1443.232009   1284.288709    2800.165478       1073.878175
# min       1.000000     52.169100       0.000000          1.000000
# 25%    1249.750000     90.562500      22.000000          8.000000
# 50%    2497.500000    157.530650      48.000000         20.000000
# 75%    3749.250000    330.427250     116.000000         50.000000
# max    5000.000000  36680.388200  155000.000000      53000.000000
#
#            founded  yrs_on_list
# count  5012.000000  5012.000000
# mean   2005.445531     2.813647
# std      30.310632     2.265986
# min       0.000000     1.000000
# 25%    2003.000000     1.000000
# 50%    2009.000000     2.000000
# 75%    2012.000000     4.000000
# max    2016.000000    14.000000

# %%
#this will help us know if we have missing data
df.isnull().sum()
# Out:
# rank                  0
# profile               0
# name                  0
# url                   0
# state                 0
# revenue               0
# growth_%              0
# industry              0
# workers               1
# previous_workers      0
# founded               0
# yrs_on_list           0
# metro               813
# city                  0
# dtype: int64

# %%
#for the purpose of this tutorial we are going to create a Dataframe, so that we merge to the old 
#using this dataset we are going to create a data frame for the percentage of previous workers 
Previous_workers_percentage= df['previous_workers']/100

Previous_workers_percentage.head()
#lets convert it into a Dataframe into the variable C
C=pd.DataFrame(Previous_workers_percentage)
C.head()
#we have converted our data into a Dataframe next is that we merge into our imported Dataframe
df['Previous_workers_percentage']=C
#lets see if our new Dataframe got merged with our odd dataframe
df.head()
# Out:
#    rank                                   profile               name  \
# 0     1      https://www.inc.com/profile/freestar           Freestar
# 1     2   https://www.inc.com/profile/freightwise        FreightWise
# 2     3  https://www.inc.com/profile/ceces-veggie  Cece's Veggie Co.
# 3     4      https://www.inc.com/profile/ladyboss           LadyBoss
# 4     5        https://www.inc.com/profile/perpay             Perpay
#
#                          url state       revenue    growth_%  \
# 0        http://freestar.com    AZ  36.9 Million  36680.3882
# 1  http://freightwisellc.com    TN  33.6 Million  30547.9317
# 2   http://cecesveggieco.com    TX  24.9 Million  23880.4852
# 3        http://ladyboss.com    NM  32.4 Million  21849.8925
# 4          http://perpay.com    PA  22.5 Million  18166.4070
#
#                        industry  workers  previous_workers  founded  \
# 0       Advertising & Marketing     40.0                 5     2015
# ...

# %% [markdown]
# SORTING DATAFRAME WITH PANDAS

# %%
#we are going to sort our Dataframe using specific criteria.
#we sorted our data based on those industry that are into Advertising and marketing
D=df['city'].unique()
A_and_M=df[df['industry'] == 'Advertising & Marketing']
A_and_M.head()
#we can also sort company based on year founded
Year_founded=df[df['founded'] == 2015]
Year_founded
# Out:
#       rank                                            profile  \
# 0        1               https://www.inc.com/profile/freestar
# 1        2            https://www.inc.com/profile/freightwise
# 2        3           https://www.inc.com/profile/ceces-veggie
# 7        8  https://www.inc.com/profile/connected-solution...
# 13      14            https://www.inc.com/profile/yieldstreet
# ...    ...                                                ...
# 4086  4077      https://www.inc.com/profile/conexus-cpa-group
# 4393  4382      https://www.inc.com/profile/five-star-connect
# 4729  4718  https://www.inc.com/profile/united-services-group
# 4810  4799        https://www.inc.com/profile/world-of-wheels
# 4894  4883           https://www.inc.com/profile/ion-exhibits
#
#                            name                        url state  \
# 0                      Freestar        http://freestar.com    AZ
# 1                   FreightWise  http://freightwisellc.com    TN
# ...

# %% [markdown]
# SLICING DATA FRAME WITH PANDAS

# %%
#data slicing is an important aspect of data science. It is used to segment a dataset based on the indexed rolls 
#we can slice the first 50 rows of our dataset
First_50=df[:50]
First_50
#we can also slice the from 1500th row to 2500th row
Second=df[1500:2500]
Second
#We can also use iloc and loc for data slicing
# Out:
#       rank                                            profile  \
# 1500  1496               https://www.inc.com/profile/rozalado
# 1501  1497       https://www.inc.com/profile/hayes-healthcare
# 1502  1498      https://www.inc.com/profile/grant-enterprises
# 1503  1499  https://www.inc.com/profile/disruptive-adverti...
# 1504  1500  https://www.inc.com/profile/proforma-angelini-...
# ...    ...                                                ...
# 2495  2487    https://www.inc.com/profile/new-breed-marketing
# 2496  2488     https://www.inc.com/profile/superior-fireworks
# 2497  2489  https://www.inc.com/profile/sweet-peach-wax-su...
# 2498  2490        https://www.inc.com/profile/injured-gadgets
# 2499  2491      https://www.inc.com/profile/lake-homes-realty
#
#                                        name                          url  \
# 1500                               Rozalado         rozaladocleaning.com
# ...

# %% [markdown]
# WORKING ON TIME WITH PANDAS

# %%
Upload=files.upload()
# Out:
#      <input type="file" id="files-7c6fc312-c4d6-4d22-ac22-f217632dceaa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c6fc312-c4d6-4d22-ac22-f217632dceaa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sampleSubmission.csv to sampleSubmission.csv

# %%
DT_data.head()
#let convert the data time format
DT=pd.to_datetime(DT_data['datetime'])
#we can now convert MIT to a dataframe
DT2=pd.DataFrame(DT)
DT2
# Out:
#                 datetime
# 0    2011-01-20 00:00:00
# 1    2011-01-20 01:00:00
# 2    2011-01-20 02:00:00
# 3    2011-01-20 03:00:00
# 4    2011-01-20 04:00:00
# ...                  ...
# 6488 2012-12-31 19:00:00
# 6489 2012-12-31 20:00:00
# 6490 2012-12-31 21:00:00
# 6491 2012-12-31 22:00:00
# 6492 2012-12-31 23:00:00
#
# [6493 rows x 1 columns]
